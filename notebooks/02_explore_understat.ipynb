# %%
import json
from pathlib import Path

RAW = Path("../data/raw/understat")
data = json.loads((RAW / "epl_2014.json").read_text(encoding="utf-8"))

print("Top-level keys:", list(data.keys()))
print("\nFirst match record:")
print(json.dumps(data["dates"][0], indent=2))

# %%
import json
from pathlib import Path

RAW = Path("../data/raw/understat")
data = json.loads((RAW / "epl_2014.json").read_text(encoding="utf-8"))

print("Top-level keys:", list(data.keys()))
print("\nFirst match record:")
print(json.dumps(data["dates"][0], indent=2))
# Out:
# Top-level keys: ['teams', 'players', 'dates']
#
# First match record:
# {
#   "id": "4749",
#   "isResult": true,
#   "h": {
#     "id": "89",
#     "title": "Manchester United",
#     "short_title": "MUN"
#   },
#   "a": {
#     "id": "84",
#     "title": "Swansea",
#     "short_title": "SWA"
#   },
#   "goals": {
#     "h": "1",
#     "a": "2"
#   },
#   "xG": {
#     "h": "1.16635",
#     "a": "0.278076"
#   },
#   "datetime": "2014-08-16 12:45:00",
#   "forecast": {
#     "w": "0.6519",
#     "d": "0.2802",
#     "l": "0.0679"
#   }
# }

# %%
import pandas as pd

df = pd.json_normalize(data["dates"])
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (380, 16)
# id                str
# isResult         bool
# datetime          str
# h.id              str
# h.title           str
# h.short_title     str
# a.id              str
# a.title           str
# a.short_title     str
# goals.h           str
# goals.a           str
# xG.h              str
# xG.a              str
# forecast.w        str
# forecast.d        str
# forecast.l        str
# dtype: object
#      id  isResult             datetime h.id               h.title  \
# 0  4749      True  2014-08-16 12:45:00   89     Manchester United
# 1  4750      True  2014-08-16 15:00:00   75             Leicester
# 2  4751      True  2014-08-16 15:00:00  202   Queens Park Rangers
# 3  4752      True  2014-08-16 15:00:00   85                 Stoke
# 4  4753      True  2014-08-16 15:00:00   76  West Bromwich Albion
#
#   h.short_title a.id      a.title a.short_title goals.h goals.a      xG.h  \
# 0           MUN   84      Swansea           SWA       1       2   1.16635
# 1           LEI   72      Everton           EVE       2       2    1.2783
# 2           QPR   91         Hull           HUL       0       1   1.90067
# 3           STO   71  Aston Villa           AVL       0       1  0.423368
# 4           WBA   77   Sunderland           SUN       2       2   1.68343
#
#        xG.a forecast.w forecast.d forecast.l
# 0  0.278076     0.6519     0.2802     0.0679
# 1  0.613273     0.5513     0.2922     0.1565
# 2   1.11757       0.59     0.2449     0.1651
# 3  0.909774     0.1468     0.3637     0.4895
# 4  0.991901     0.5894     0.2676      0.143

# %%
fd = pd.read_csv("../data/processed/matches.csv")
fd_teams = set(fd["home_team"])

us_teams = set()
for f in sorted(RAW.glob("epl_*.json")):
    season = json.loads(f.read_text(encoding="utf-8"))
    us_teams |= {m["h"]["title"] for m in season["dates"]}

print(f"football-data: {len(fd_teams)} teams | Understat: {len(us_teams)} teams\n")
print("Same name in both:     ", len(fd_teams & us_teams))
print("Only in football-data: ", sorted(fd_teams - us_teams))
print("Only in Understat:     ", sorted(us_teams - fd_teams))
# Out:
# football-data: 35 teams | Understat: 35 teams
#
# Same name in both:      28
# Only in football-data:  ['Man City', 'Man United', 'Newcastle', "Nott'm Forest", 'QPR', 'West Brom', 'Wolves']
# Only in Understat:      ['Manchester City', 'Manchester United', 'Newcastle United', 'Nottingham Forest', 'Queens Park Rangers', 'West Bromwich Albion', 'Wolverhampton Wanderers']
